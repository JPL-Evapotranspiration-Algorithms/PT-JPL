# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import rasters as rt
from PTJPL import PTJPL, process_PTJPL_table
from PTJPL import load_Topt, load_fAPARmax

# %%
tower_data_filename = "combined_eco_flux_EC_filtered.csv"
tower_locations_filename = "metadata_ebc_filt.csv"

# %%
tower_locations_df = pd.read_csv(tower_locations_filename)
tower_locations_df
# Out:
#     Site ID                                          Name      Lat      Long  \
# 0    US-NC3                                 NC_Clearcut#3  35.7990  -76.6560
# 1    PE-QFR                    Quistococha Forest Reserve  -3.8344  -73.3190
# 2    US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3  41.8222  -80.6370
# 3    US-NC4                             NC_AlligatorRiver  35.7879  -75.9038
# 4    CA-DB2                             Delta Burns Bog 2  49.1190 -122.9951
# ..      ...                                           ...      ...       ...
# 116  US-xSL                NEON North Sterling, CO (STER)  40.4619 -103.0293
# 117  US-xWD                         NEON Woodworth (WOOD)  47.1282  -99.2414
# 118  US-CS4    Central Sands Irrigated Agricultural Field  44.1597  -89.5475
# 119  US-xAE     NEON Klemme Range Research Station (OAES)  35.4106  -99.0588
# 120  US-GLE                                         GLEES  41.3665 -106.2399
#
#        Elev Clim  Veg   MAT      MAP      StartDate         EndDate  LE_count  \
# 0       5.0  Cfa  ENF  16.6  1320.00  10/1/18 05:00    1/1/22 05:00      9576
# 1     104.0   Af  WET   NaN      NaN  10/1/18 05:00    1/1/20 05:00      6859
# 2     270.0  Dfb  CVM  10.5  1012.70  10/1/18 05:00  12/28/19 04:00     12170
# 3       1.0  Cfa  WET  16.6  1311.00  10/1/18 05:00    1/1/22 05:00     20890
# 4       4.0  NaN  WET   NaN      NaN   1/1/19 08:30    1/1/21 08:00     11884
# ..      ...  ...  ...   ...      ...            ...             ...       ...
# 116  1364.0  Bsk  CRO   9.7   432.67  10/1/18 07:00   12/1/22 00:00     23176
# 117   579.0  Dfb  GRA   4.9   493.76  10/1/18 06:00   12/1/22 00:00     20494
# 118   328.0  Dfa  CRO   7.0   830.00   1/1/20 06:30   4/27/21 06:00      6359
# 119   516.0  Cfa  GRA  15.5   778.85  10/1/18 06:00   12/1/22 00:00     29615
# 120  3197.0  Dfc  ENF   0.8  1200.00  10/1/18 07:00   10/1/20 07:00     20896
#
#      closure_ratio
# 0             1.02
# 1             0.98
# 2             0.92
# 3             0.90
# 4             0.89
# ..             ...
# 116           0.60
# 117           0.60
# 118           0.60
# 119           0.60
# 120           0.60
#
# [121 rows x 13 columns]

# %%
tower_IDs = list(tower_locations_df["Site ID"])
tower_IDs
# Out:
# ['US-NC3',
#  'PE-QFR',
#  'US-Mi3',
#  'US-NC4',
#  'CA-DB2',
#  'US-Sne',
#  'US-Mi1',
#  'US-PFe',
#  'US-NR1',
#  'US-Vcp',
#  'US-xAB',
#  'US-HBK',
#  'US-EDN',
#  'US-PFh',
#  'US-Me6',
#  'US-NC2',
#  'US-Whs',
#  'US-SRM',
#  'US-CS1',
#  'US-PFs',
#  'US-PFg',
#  'US-Ha1',
#  'US-Ne2',
#  'US-PFm',
#  'US-PFr',
#  'US-PFL',
#  'US-PFj',
#  'US-CC2',
#  'US-NR3',
#  'US-PFt',
#  'CA-Cbo',
#  'PR-xLA',
#  'US-Ne3',
#  'US-PHM',
#  'US-Tw1',
#  'US-Hn3',
#  'US-PFk',
#  'US-CS2',
#  'US-ONA',
#  'US-CC1',
#  'US-Rls',
#  'US-UMd',
#  'US-PFq',
#  'US-PFn',
#  'US-HB3',
#  'US-DFC',
#  'US-Wkg',
#  'US-CF1',
#  'US-Ho2',
#  'US-Snf',
#  'US-Me2',
#  'US-CF3',
#  'US-Ne1',
#  'US-Ha2',
#  'CA-Ca3',
#  'US-SP1',
#  'US-UMB',
#  'US-Bi1',
#  'US-PFi',
#  'US-CF2',
#  'US-KFS',
#  'US-CMW',
#  'US-Ro4',
#  'US-PAS',
#  'US-xYE',
#  'US-Los',
#  'US-PFd',
#  'US-KM4',
#  'US-Syv',
#  'US-WCr',
#  'US-Rws',
#  'US-xJE',
#  'US-SRG',
#  'US-xNW',
#  'US-Rms',
#  'US-NR4',
#  'US-xDS',
#  'US-xJR',
#  'US-Bar',
#  'US-ALQ',
#  'US-MMS',
#  'US-UC1',
#  'US-PFb',
#  'US-xDL',
#  'US-xPU',
#  'US-xBL',
#  'US-xST',
#  'US-xSB',
#  'US-xRN',
#  'US-UC2',
#  'US-xTR',
#  'US-xRM',
#  'US-Tw4',
#  'US-Bi2',
#  'US-Jo2',
#  'US-CS5',
#  'US-Mpj',
#  'US-xWR',
#  'US-xUK',
#  'US-xUN',
#  'US-xBR',
#  'US-CF4',
#  'US-xCL',
#  'CA-DBB',
#  'US-Hn2',
#  'US-PFp',
#  'US-xKA',
#  'US-CS3',
#  'US-xTE',
#  'US-Rwf',
#  'US-xML',
#  'US-UiB',
#  'PR-xGU',
#  'US-ARM',
#  'US-Kon',
#  'US-HB2',
#  'US-xSL',
#  'US-xWD',
#  'US-CS4',
#  'US-xAE',
#  'US-GLE']

# %%
tower_names = list(tower_locations_df.Name)
tower_names
# Out:
# ['NC_Clearcut#3',
#  'Quistococha Forest Reserve',
#  'LTAR UCB (Upper Chesapeake Bay) Miscanthus 3',
#  'NC_AlligatorRiver',
#  'Delta Burns Bog 2',
#  'Sherman Island Restored Wetland',
#  'LTAR UCB (Upper Chesapeake Bay) Miscanthus 1',
#  'NW4 Lake-1 CHEESEHEAD 2019',
#  'Niwot Ridge Forest (LTER NWT1)',
#  'Valles Caldera Ponderosa Pine',
#  'NEON Abby Road (ABBY)',
#  'Hubbard Brook Experimental Forest',
#  'Eden Landing Ecological Reserve',
#  'NE2 Pine-3 CHEESEHEAD 2019',
#  'Metolius Young Pine Burn',
#  'NC_Loblolly Plantation',
#  'Walnut Gulch Lucky Hills Shrub',
#  'Santa Rita Mesquite',
#  'Central Sands Irrigated Agricultural Field',
#  'SE5 Aspen-5 CHEESEHEAD 2019',
#  'NE1 Pine-2 CHEESEHEAD 2019',
#  'Harvard Forest EMS Tower (HFR1)',
#  'Mead - irrigated maize-soybean rotation site',
#  'SW3 Hardwood-2 CHEESEHEAD 2019',
#  'SE4 Tussock-2 CHEESEHEAD 2019',
#  'SW2 Aspen-3 CHEESEHEAD 2019',
#  'NE4 Maple-1 CHEESEHEAD 2019',
#  'Coloma Corn 2',
#  'Niwot Ridge Alpine (T-Van West)',
#  'SE6 Pine-4 CHEESEHEAD 2019',
#  'Ontario - Mixed Deciduous, Borden Forest Site',
#  'NEON Lajas Experimental Station (LAJA)',
#  'Mead - rainfed maize-soybean rotation site',
#  'Plum Island High Marsh',
#  'Twitchell Wetland West Pond',
#  'Hanford 100H sagebrush',
#  'SW1 Aspen-2 CHEESEHEAD 2019',
#  'Tri county school Pine Forest',
#  'Florida pine flatwoods',
#  'Coloma Corn 1',
#  'RCEW Low Sagebrush',
#  'UMBS Disturbance',
#  'SE3 Aspen-4 CHEESEHEAD 2019',
#  'SW4 Hardwood-3 CHEESEHEAD 2019',
#  'Hobcaw Barony Longleaf Pine Restoration',
#  'US Dairy Forage Research Center, Prairie du Sac',
#  'Walnut Gulch Kendall Grasslands',
#  'CAF-LTAR Cook East',
#  'Howland Forest (west tower)',
#  'Sherman Barn',
#  'Metolius mature ponderosa pine',
#  'CAF-LTAR Boyd North',
#  'Mead - irrigated continuous maize site',
#  'Harvard Forest Hemlock Site',
#  'British Columbia - Pole sapling Douglas-fir stand',
#  'Slashpine-Austin Cary- 65yrs nat regen',
#  'Univ. of Mich. Biological Station',
#  'Bouldin Island Alfalfa',
#  'NE3 Hardwood-1 CHEESEHEAD 2019',
#  'CAF-LTAR Cook West',
#  'Kansas Field Station',
#  'Charleston Mesquite Woodland',
#  'Rosemount Prairie',
#  'Florida, Paspalum notatum pasture',
#  'NEON Yellowstone Northern Range (Frog Rock) (YELL)',
#  'Lost Creek',
#  'NW3 Tussock-1 CHEESEHEAD 2019',
#  'KBS Marshall Farms Smooth Brome Grass (Ref)',
#  'Sylvania Wilderness Area',
#  'Willow Creek',
#  'Reynolds Creek Wyoming big sagebrush',
#  'NEON Jones Ecological Research Center (JERC)',
#  'Santa Rita Grassland',
#  'NEON Niwot Ridge Mountain Research Station (NIWO)',
#  'RCEW Mountain Big Sagebrush',
#  'Niwot Ridge Alpine (T-Van East)',
#  'NEON Disney Wilderness Preserve (DSNY)',
#  'NEON Jornada LTER (JORN)',
#  'Bartlett Experimental Forest',
#  'Allequash Creek Site',
#  'Morgan Monroe State Forest',
#  'LTAR UCB (Upper Chesapeake Bay) EC1',
#  'NW1 Pine-1 CHEESEHEAD 2019',
#  'NEON Dead Lake (DELA)',
#  "NEON Pu'u Maka'ala Natural Area Reserve (PUUM)",
#  'NEON Blandy Experimental Farm (BLAN)',
#  'NEON Steigerwaldt Land Services (STEI)',
#  'NEON Ordway-Swisher Biological Station (OSBS)',
#  'NEON Oak Ridge National Lab (ORNL)',
#  'LTAR UCB (Upper Chesapeake Bay) EC2',
#  'NEON Treehaven (TREE)',
#  'NEON Rocky Mountain National Park, CASTNET (RMNP)',
#  'Twitchell East End Wetland',
#  'Bouldin Island corn',
#  'Jornada Experimental Range Mixed Shrubland',
#  'Central Sands Irrigated Agricultural Field',
#  'Mountainair Pinyon-Juniper Woodland',
#  'NEON Wind River Experimental Forest (WREF)',
#  'NEON The University of Kansas Field Station (UKFS)',
#  'NEON University of Notre Dame Environmental Research Center (UNDE)',
#  'NEON Bartlett Experimental Forest (BART)',
#  'CAF-LTAR Boyd South',
#  'NEON LBJ National Grassland (CLBJ)',
#  'Delta Burns Bog',
#  'Hanford 100H grassland',
#  'SE2 Hardwood-4 CHEESEHEAD 2019',
#  'NEON Konza Prairie Biological Station - Relocatable (KONA)',
#  'Central Sands Irrigated Agricultural Field',
#  'NEON Lower Teakettle (TEAK)',
#  'RCEW Upper Sheep Prescibed Fire',
#  'NEON Mountain Lake Biological Station (MLBS)',
#  'University of Illinois Miscanthus',
#  'NEON Guanica Forest (GUAN)',
#  'ARM Southern Great Plains site- Lamont',
#  'Konza Prairie LTER (KNZ)',
#  'Hobcaw Barony Mature Longleaf Pine',
#  'NEON North Sterling, CO (STER)',
#  'NEON Woodworth (WOOD)',
#  'Central Sands Irrigated Agricultural Field',
#  'NEON Klemme Range Research Station (OAES)',
#  'GLEES']

# %%
tower_data_df = pd.read_csv(tower_data_filename)
tower_data_df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...  ESIrn_STIC  \
# 0     392.851840   307.021970  487.383423         118.916280  ...    0.686404
# 1     640.118470   375.089300  106.825577         167.919460  ...    0.360762
# 2     625.661700   284.686250         NaN         132.936340  ...    0.566752
# 3     624.254330   251.414490  178.827545         141.132420  ...    0.531036
# 4     511.082180   228.520170  154.791626         114.809410  ...    0.559024
# ...          ...          ...         ...                ...  ...         ...
# 1060   81.645230    15.282976         NaN          56.385185  ...    0.434453
# 1061   65.469320    22.186659         NaN          40.509410  ...    0.701256
# 1062  118.777240    55.343586         NaN          52.403820  ...    0.550616
# 1063  126.490524    40.434025         NaN          57.769722  ...    0.010924
# 1064  271.749480   119.763630  190.823303         122.092445  ...    0.557206
#
#       ESIrn_PTJPLSM  ESIrn_MOD16  ESIrn_BESS  ESIrn_Unc_ECO  ESIrn_LEcorr50  \
# 0          0.779526     0.997448    0.199396       0.301927        0.737734
fAPARmax = load_fAPARmax(geometry=tower_points)
fAPARmax
# Out:
# array([0.4659, 0.5924, 0.4865, 0.5777, 0.4949, 0.3557, 0.4792, 0.4739,
#        0.4462, 0.4323, 0.604 , 0.5306, 0.2956, 0.4958, 0.4851, 0.5663,
#        0.2522, 0.2773, 0.4053, 0.4951, 0.4966, 0.5545, 0.397 , 0.4877,
#        0.4951, 0.4877, 0.4958, 0.4045, 0.3301, 0.4951, 0.4508, 0.5173,
#        0.4027, 0.4003, 0.4334, 0.2898, 0.4877, 0.4053, 0.5321, 0.4566,
#        0.2933, 0.4422, 0.4951, 0.4872, 0.5752, 0.4192, 0.2651, 0.3501,
#        0.566 , 0.4022, 0.5123, 0.3514, 0.397 , 0.5545, 0.6107, 0.5694,
#        0.4431, 0.4416, 0.4958, 0.3501, 0.4779, 0.2761, 0.404 , 0.5321,
#        0.3157, 0.4642, 0.4739, 0.4639, 0.4913, 0.4989, 0.2906, 0.4944,
#        0.3329, 0.3301, 0.3586, 0.3301, 0.5168, 0.2447, 0.5215, 0.4607,
#        0.5483, 0.4962, 0.4739, 0.4725, 0.5117, 0.497 , 0.4671, 0.5047,
#        0.5194, 0.5016, 0.4761, 0.4423, 0.4334, 0.409 , 0.2331, 0.4053,
#        0.3176, 0.6244, 0.4664, 0.4592, 0.5215, 0.3514, 0.4322, 0.4949,
#        0.2898, 0.4872, 0.4122, 0.3904, 0.4248, 0.2933, 0.5404, 0.406 ,
#        0.5546, 0.4017, 0.4233, 0.5752, 0.3046, 0.3626, 0.3903, 0.3387,
#        0.3462])

# %%
tower_static_data_gdf = gpd.GeoDataFrame({
    "ID": tower_IDs,
    "name": tower_names,
    "Topt": Topt,
    "fAPARmax": fAPARmax,
    "geometry": tower_points
})

tower_static_data_gdf
# Out:
#          ID                                          name   Topt  fAPARmax  \
# 0    US-NC3                                 NC_Clearcut#3  10.09    0.4659
# 1    PE-QFR                    Quistococha Forest Reserve  25.06    0.5924
# 2    US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# 3    US-NC4                             NC_AlligatorRiver   9.74    0.5777
# 4    CA-DB2                             Delta Burns Bog 2   3.43    0.4949
# ..      ...                                           ...    ...       ...
# 116  US-xSL                NEON North Sterling, CO (STER)   0.66    0.3046
# 117  US-xWD                         NEON Woodworth (WOOD)   0.00    0.3626
# 118  US-CS4    Central Sands Irrigated Agricultural Field   0.00    0.3903
# 119  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 120  US-GLE                                         GLEES   0.00    0.3462
#
#                       geometry
# 0       POINT (-76.656 35.799)
# 1      POINT (-73.319 -3.8344)
# 2      POINT (-80.637 41.8222)
# 3     POINT (-75.9038 35.7879)
# 4     POINT (-122.9951 49.119)
# ..                         ...
# 116  POINT (-103.0293 40.4619)
# 117   POINT (-99.2414 47.1282)
# 118   POINT (-89.5475 44.1597)
# 119   POINT (-99.0588 35.4106)
# 120  POINT (-106.2399 41.3665)
#
# [121 rows x 5 columns]

# %%
for key in sorted(tower_data_df.keys()):
    print(key)
# Out:
# AirTempC
# BESSinst
# Date-Time
# ESI
# ESIrn_BESS
# ESIrn_LEcorr50
# ESIrn_MOD16
# ESIrn_PTJPLSM
# ESIrn_STIC
# ESIrn_Unc_ECO
# ETinst
# ETinstUncertainty
# EmisWB
# G_filt
# H_filt
# Hcorr25
# Hcorr50
# Hcorr75
# Hcorr_ann
# ID
# JET
# LE
# LE_filt
# LEcorr25
# LEcorr50
# LEcorr75
# LEcorr_ann
# LST
# LST_err
# MOD16inst
# NDVI
# NDVI-UQ
# NETRAD_filt
# PET
# PTJPLSMinst
# RH
# RH_percentage
# Rg
# Rn
# SM
# SM_rz
# SM_surf
# STICinst
# SW_IN
# Site Name
# Ta
# Unnamed: 0
# albedo
# albedo-UQ
# climate
# eco_time_utc
# local_time
# solar_hour
# solar_time
# time_utc
# vegetation
# view_zenith

# %%
observation_tower_IDs = list(tower_data_df.ID)
print(len(observation_tower_IDs))
observation_tower_IDs[:10]
# Out:
# 1065
# ['US-NC3',
#  'US-Mi3',
#  'US-Mi3',
#  'US-Mi3',
#  'US-Mi3',
#  'US-Mi3',
#  'US-NC4',
#  'US-Mi1',
#  'US-Mi1',
#  'US-Mi1']

# %%
model_inputs_df = pd.DataFrame({
    "ID": observation_tower_IDs,
})

model_inputs_df = pd.merge(
    left=model_inputs_df, 
    right=tower_static_data_gdf, 
    left_on="ID", 
    right_on="ID", 
    how="left"
)

model_inputs_df
# Out:
#           ID                                          name   Topt  fAPARmax  \
# 0     US-NC3                                 NC_Clearcut#3  10.09    0.4659
# 1     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# 2     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# 3     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# 4     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# ...      ...                                           ...    ...       ...
# 1060  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 1061  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 1062  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 1063  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 1064  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
#
#                       geometry
# 0       POINT (-76.656 35.799)
# 1      POINT (-80.637 41.8222)
# 2      POINT (-80.637 41.8222)
# 3      POINT (-80.637 41.8222)
# 4      POINT (-80.637 41.8222)
# ...                        ...
# 1060  POINT (-99.0588 35.4106)
# 1061  POINT (-99.0588 35.4106)
# 1062  POINT (-99.0588 35.4106)
# 1063  POINT (-99.0588 35.4106)
# 1064  POINT (-99.0588 35.4106)
#
# [1065 rows x 5 columns]

# %%
ST_K = np.array(tower_data_df.LST)
model_inputs_df["ST_K"] = ST_K
print(np.nanmin(ST_K), np.nanmean(ST_K), np.nanmax(ST_K))
# Out:
# 258.72 302.1800469295775 359.26

# %%
ST_C = ST_K - 273.15
model_inputs_df["ST_C"] = ST_C
print(np.nanmin(ST_C), np.nanmean(ST_C), np.nanmax(ST_C))
# Out:
# -14.42999999999995 29.030046929577487 86.11000000000001

# %%
NDVI = np.array(tower_data_df.NDVI)
model_inputs_df["NDVI"] = NDVI
print(np.nanmin(NDVI), np.nanmean(NDVI), np.nanmax(NDVI))
# Out:
# -0.02429185 0.4528892517239436 0.94546

# %%
Ta_C = np.array(tower_data_df.Ta)
model_inputs_df["Ta_C"] = Ta_C
print(np.nanmin(Ta_C), np.nanmean(Ta_C), np.nanmax(Ta_C))
# Out:
# -14.605048 22.321587967441317 39.710495

# %%
RH = np.array(tower_data_df.RH)
model_inputs_df["RH"] = RH
print(np.nanmin(RH), np.nanmean(RH), np.nanmax(RH))
# Out:
# 0.27253073 0.42692000418779347 0.98366296

# %%
Rg = np.array(tower_data_df.Rg)
model_inputs_df["Rg"] = Rg
print(np.nanmin(Rg), np.nanmean(Rg), np.nanmax(Rg))
# Out:
# -23.763361 606.9121518676056 1042.9371

# %%
Rn = np.array(tower_data_df.Rn)
model_inputs_df["Rn"] = Rn
print(np.nanmin(Rn), np.nanmean(Rn), np.nanmax(Rn))
# Out:
# 0.0 414.2791522507042 763.1359

# %%
albedo = np.array(tower_data_df.albedo)
model_inputs_df["albedo"] = albedo
print(np.nanmin(albedo), np.nanmean(albedo), np.nanmax(albedo))
# Out:
# 0.015407953 0.10903688726384977 0.6173986

# %%
model_inputs_df
# Out:
#           ID                                          name   Topt  fAPARmax  \
# 0     US-NC3                                 NC_Clearcut#3  10.09    0.4659
# 1     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# 2     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# 3     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# 4     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
# ...      ...                                           ...    ...       ...
# 1060  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 1061  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 1062  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 1063  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
# 1064  US-xAE     NEON Klemme Range Research Station (OAES)   7.99    0.3387
#
#                       geometry    ST_K   ST_C      NDVI       Ta_C        RH  \
# 0       POINT (-76.656 35.799)  305.10  31.95  0.709729  32.658920  0.560215
# 1      POINT (-80.637 41.8222)  304.34  31.19  0.605842  24.227982  0.458503
# 2      POINT (-80.637 41.8222)  304.06  30.91  0.578494  26.178862  0.621679
# 3      POINT (-80.637 41.8222)  301.80  28.65  0.658499  22.527096  0.623986
# 4      POINT (-80.637 41.8222)  303.18  30.03  0.666747  23.280691  0.571613
# ...                        ...     ...    ...       ...        ...       ...
# 1060  POINT (-99.0588 35.4106)  278.78   5.63  0.268441   3.815752  0.395740
# 1061  POINT (-99.0588 35.4106)  293.28  20.13  0.225175  19.266186  0.397430
# 1062  POINT (-99.0588 35.4106)  301.94  28.79  0.282996  32.110336  0.341227
# 1063  POINT (-99.0588 35.4106)  290.72  17.57  0.284051  10.464681  0.349086
# 1064  POINT (-99.0588 35.4106)  314.76  41.61  0.279265  30.316103  0.383591
#
#              Rg         Rn    albedo
# 0     545.51056  393.85710  0.215445
# 1     848.34390  643.47500  0.117238
# 2     838.81160  628.76870  0.117280
# 3     851.72480  626.95960  0.084629
# 4     702.55160  513.13380  0.120526
# ...         ...        ...       ...
# 1060  286.84660  163.24739  0.092853
# 1061  290.87400  166.19196  0.111844
# 1062  352.19530  235.88159  0.106782
# 1063  420.67880  247.87890  0.106775
# 1064  781.84110  544.22034  0.113165
#
# [1065 rows x 13 columns]

# %%
model_inputs_df.keys()
# Out:
# Index(['ID', 'name', 'Topt', 'fAPARmax', 'geometry', 'ST_K', 'ST_C', 'NDVI',
#        'Ta_C', 'RH', 'Rg', 'Rn', 'albedo'],
#       dtype='object')

# %%
model_inputs_df.albedo
# Out:
# 0       0.215445
# 1       0.117238
# 2       0.117280
# 3       0.084629
# 4       0.120526
#           ...
# 1060    0.092853
# 1061    0.111844
# 1062    0.106782
# 1063    0.106775
# 1064    0.113165
# Name: albedo, Length: 1065, dtype: float64

# %%
results = process_PTJPL_table(model_inputs_df)
results
# Out:
# [2025-07-21 17:41:58 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-21 17:41:58 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
#           ID                                          name   Topt  fAPARmax  \
# 0     US-NC3                                 NC_Clearcut#3  10.09    0.4659
# 1     US-Mi3  LTAR UCB (Upper Chesapeake Bay) Miscanthus 3   1.39    0.4865
#